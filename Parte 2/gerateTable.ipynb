# %%
import pandas as pd
from datetime import datetime, timedelta
import random

# Função para gerar dados realistas
def generate_data():
    # Tabela USER
    users_data = pd.DataFrame({
        'UserID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
        'UserName': ['LucasVlog', 'MariArtista', 'TechGuruJoao', 'AnaCozinha', 'PedroGames', 
                     'SofiaViagens', 'RafaelMusica', 'JuliaFitness', 'CarlosDIY', 'BeatrizEstudo'],
        'UserEmail': ['lucas.vlog@gmail.com', 'mari.artista@outlook.com', 'joao_tech@yahoo.com', 
                      'ana.cozinha@hotmail.com', 'pedro_gamer@gmail.com', 'sofia.viaja@proton.me', 
                      'rafa.musica@icloud.com', 'julia.fit@live.com', 'carlos.diy@gmail.com', 
                      'bia_estudo@edu.br'],
        'UserPassword': ['Lvc#2023', 'M@riArt99', 'Tech!Joao22', 'Cozinh@Ana', 'GameP3dro!', 
                         'Sof!Viaj88', 'RafaM#usic', 'FitJul!a77', 'DIY#Carlos', 'BiaEstud0!'],
        'UserPhoto': ['photo_lucas.jpg', 'photo_mari.jpg', 'photo_joao.jpg', 'photo_ana.jpg', 
                      'photo_pedro.jpg', 'photo_sofia.jpg', 'photo_rafael.jpg', 'photo_julia.jpg', 
                      'photo_carlos.jpg', 'photo_beatriz.jpg']
    })

    # Tabela CHANNEL
    channels_data = pd.DataFrame({
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
        'UserID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
        'ChannelURL': ['mimi.com/lucasvlog', 'mimi.com/mariarte', 'mimi.com/techjoao', 
                       'mimi.com/cozinhaana', 'mimi.com/pedrogames', 'mimi.com/viagenssofia', 
                       'mimi.com/rafamusica', 'mimi.com/juliafit', 'mimi.com/carlosdiy', 
                       'mimi.com/biaestudos'],
        'CHCreationDate': [datetime(2025, 4, 4), datetime(2024, 8, 23), datetime(2025, 1, 15), 
                           datetime(2024, 11, 30), datetime(2024, 9, 10), datetime(2025, 3, 5), 
                           datetime(2025, 4, 3), datetime(2024, 7, 19), datetime(2024, 6, 25), 
                           datetime(2025, 3, 17)],
        'CHName': ['Lucas Vlogs', 'Mari Arte', 'Tech com Joao', 'Cozinha da Ana', 'Pedro Games', 
                   'Viagens da Sofia', 'Rafa Musica', 'Julia Fitness', 'Carlos DIY', 'Bia Estudos'],
        'CHDesc': ['Vlogs diarios e aventuras!', 'Tutoriais de arte e pintura.', 'Reviews de tecnologia.', 
                   'Receitas faceis e gostosas.', 'Gameplays e dicas de jogos.', 'Dicas de viagem pelo mundo.', 
                   'Covers e aulas de musica.', 'Treinos e vida saudavel.', 'Projetos faca-voce-mesmo.', 
                   'Dicas de estudo e produtividade.'],
        'CHWelcomeVID': ['mimi.com/welcome_lucas', 'mimi.com/welcome_mari', 'mimi.com/welcome_joao', 
                         'mimi.com/welcome_ana', 'mimi.com/welcome_pedro', 'mimi.com/welcome_sofia', 
                         'mimi.com/welcome_rafa', 'mimi.com/welcome_julia', 'mimi.com/welcome_carlos', 
                         'mimi.com/welcome_bia'],
        'CHBanner': ['banner_lucas.jpg', 'banner_mari.jpg', 'banner_joao.jpg', 'banner_ana.jpg', 
                     'banner_pedro.jpg', 'banner_sofia.jpg', 'banner_rafael.jpg', 'banner_julia.jpg', 
                     'banner_carlos.jpg', 'banner_bia.jpg'],
    })

    # Tabela UADMINCH
    uadminch_data = pd.DataFrame({
        'UserID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210]
    })

    # Tabela UINTERESTCH
    uinterestch_data = pd.DataFrame({
        'UserID': [102, 103, 104, 105, 106, 107, 108, 109, 110, 101],
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
        'UisSubToCH': [True, True, False, True, True, False, True, True, False, True],
        'UMemberLevelCH': [1, 2, 0, 3, 1, 0, 2, 1, 0, 3],
        'UisNotifiedByCH': [True, False, True, True, False, True, True, False, True, True]
    })

    # Tabela CONTENT
    content_data = pd.DataFrame({
        'ContentID': [301, 302, 303, 304, 305, 306, 307, 308, 309, 310],
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
        'ContentURL': ['mimi.com/vlog_paris', 'mimi.com/arte_aquarela', 'mimi.com/review_iphone', 
                       'mimi.com/receita_bolo', 'mimi.com/gameplay_cod', 'mimi.com/viagem_japao', 
                       'mimi.com/cover_rock', 'mimi.com/treino_hiit', 'mimi.com/diy_mesa', 
                       'mimi.com/estudo_matematica'],
        'CONTTitle': ['Vlog em Paris', 'Aquarela para Iniciantes', 'Review iPhone 15', 'Bolo de Chocolate Facil', 
                      'Gameplay COD Warzone', 'Viagem ao Japao', 'Cover de Rock Classico', 'Treino HIIT 20min', 
                      'DIY Mesa de Madeira', 'Como Estudar Matematica'],
        'CONTPubDateTime': [datetime(2024, 10, 5), datetime(2024, 12, 15), datetime(2024, 9, 20), 
                            datetime(2025, 3, 10), datetime(2024, 11, 25), datetime(2024, 4, 12), 
                            datetime(2024, 6, 30), datetime(2024, 8, 15), datetime(2024, 7, 10), 
                            datetime(2024, 5, 22)],
        'CONTStatus': [True, True, True, True, False, True, True, True, True, True],
        'CONTCategory': ['Vlog', 'Arte', 'Tecnologia', 'Culinaria', 'Gaming', 'Viagem', 'Musica', 
                         'Fitness', 'DIY', 'Educacao'],
        'CONTLanguage': ['pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 
                         'pt-BR', 'pt-BR'],
        'CONTThum': ['thumb_paris.jpg', 'thumb_aquarela.jpg', 'thumb_iphone.jpg', 'thumb_bolo.jpg', 
                      'thumb_cod.jpg', 'thumb_japao.jpg', 'thumb_rock.jpg', 'thumb_hiit.jpg', 
                      'thumb_mesa.jpg', 'thumb_matematica.jpg'],
        'CONTDesc': ['Um dia incrivel em Paris!', 'Aprenda aquarela passo a passo.', 'Tudo sobre o iPhone 15.', 
                     'Receita simples de bolo.', 'Jogando COD com amigos.', 'Explorando o Japao.', 
                     'Cover de uma musica classica.', 'Treino intenso em casa.', 'Construindo uma mesa.', 
                     'Dicas para estudar matematica.'],
        'CONTCaptionLanguage': ['pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 'pt-BR', 
                                'pt-BR', 'pt-BR'],
        'CONTIndRating': ['L', 'L', '10', 'L', '16', 'L', '12', 'L', 'L', '16'],
    })

    # Tabela UWATCHINGCONT
    uwatchingcont_data = pd.DataFrame({
        'UWATCHCONTID': [401, 402, 403, 404, 405, 406, 407, 408, 409, 410],
        'UserID': [102, 103, 104, 105, 106, 107, 108, 109, 110, 101],
        'ContentID': [301, 302, 303, 304, 305, 306, 307, 308, 309, 310],
        'UWatchDurationCONT': [15.3, 8.7, 12.1, 5.9, 25.0, 18.4, 10.2, 7.5, 9.8, 14.6],
        'UWatchCONTDateTime': [datetime(2024, 10, 6), datetime(2024, 12, 16), datetime(2024, 9, 21), 
                               datetime(2025, 3, 11), datetime(2024, 11, 26), datetime(2024, 4, 13), 
                               datetime(2024, 7, 1), datetime(2024, 8, 16), datetime(2024, 7, 11), 
                               datetime(2024, 5, 23)],
        'UIsWatchingCONTNow': [False, False, True, False, False, True, False, False, True, False]
    })

    # Tabela LIVE
    live_data = pd.DataFrame({
    'ContentID': [301, 303, 305, 307, 309, 302, 304, 306, 308, 310],
    'LIVEBody': ['live_stream_paris.ts', 'live_stream_iphone_review.ts', 
                 'live_stream_cod_gameplay.ts', 'live_stream_rock_cover.ts', 
                 'live_stream_diy_mesa.ts', 'live_stream_aquarela_aula.ts', 
                 'live_stream_bolo_cozinha.ts', 'live_stream_japao_viagem.ts', 
                 'live_stream_hiit_treino.ts', 'live_stream_matematica_aula.ts']
})

    # Tabela VIDEO
    video_data = pd.DataFrame({
        'ContentID': [302, 304, 306, 308, 310, 301, 303, 305, 307, 309],
        'VIDEOBody': ['video_aquarela.mp4', 'video_bolo.mp4', 'video_japao.mp4', 'video_hiit.mp4', 
                      'video_matematica.mp4', 'video_paris.mp4', 'video_iphone.mp4', 'video_cod.mp4', 
                      'video_rock.mp4', 'video_mesa.mp4']
    })

    # Tabela COMMENT
    comment_data = pd.DataFrame({
        'CommentID': [501, 502, 503, 504, 505, 506, 507, 508, 509, 510],
        'UserID': [102, 103, 104, 105, 106, 107, 108, 109, 110, 101],
        'COMDateTime': [datetime(2024, 10, 6), datetime(2024, 12, 17), datetime(2024, 9, 22), 
                        datetime(2024, 3, 12), datetime(2024, 11, 27), datetime(2024, 4, 14), 
                        datetime(2024, 7, 2), datetime(2024, 8, 17), datetime(2024, 7, 12), 
                        datetime(2024, 5, 24)],
        'COMisEdited': [False, True, False, False, True, False, False, True, False, False],
        'COMBody': ['Adorei o vlog!', 'Otima tecnica de pintura.', 'Vale a pena comprar?', 
                    'Fiz o bolo e ficou otimo!', 'Que gameplay insano!', 'Quero visitar o Japao!', 
                    'Amei o cover!', 'Treino top, vou tentar.', 'Mesa ficou linda!', 'Me ajudou muito!']
    })

    # Tabela LIVECOMMENT
    livecomment_data = pd.DataFrame({
        'CommentID': [501, 503, 505, 507, 509, 502, 504, 506, 508, 510],
        'ContentID': [301, 303, 305, 307, 309, 302, 304, 306, 308, 310]
    })

    # Tabela COMMENTREPLY
    commentreply_data = pd.DataFrame({
        'CommentID': [501, 502, 503, 504, 505, 506, 507, 508, 509, 510],
        'COMisRepByCOMCommentID': [502, 501, 504, 503, 506, 505, 508, 507, 510, 509]
    })

    # Tabela POLL
    poll_data = pd.DataFrame({
        'POLLID': [601, 602, 603, 604, 605, 606, 607, 608, 609, 610],
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
        'POLLPubDateTime': [datetime(2024, 10, 7), datetime(2024, 12, 18), datetime(2024, 9, 23), 
                            datetime(2025, 3, 13), datetime(2024, 11, 28), datetime(2024, 4, 15), 
                            datetime(2024, 7, 3), datetime(2024, 8, 18), datetime(2024, 7, 13), 
                            datetime(2024, 5, 25)],
        'POLLURL': ['mimi.com/poll_paris', 'mimi.com/poll_arte', 'mimi.com/poll_iphone', 
                    'mimi.com/poll_bolo', 'mimi.com/poll_cod', 'mimi.com/poll_japao', 
                    'mimi.com/poll_rock', 'mimi.com/poll_hiit', 'mimi.com/poll_mesa', 
                    'mimi.com/poll_matematica'],
        'POLLBody': ['Qual o proximo destino do vlog?', 'Qual tecnica de arte voce prefere?', 
                     'Qual celular voce compraria?', 'Qual sabor de bolo voce gosta?', 
                     'Qual jogo devo jogar?', 'Qual pais visitar depois?', 'Qual estilo musical prefere?', 
                     'Qual treino voce quer ver?', 'Qual projeto DIY fazer?', 'Qual materia estudar?']
    })

    # Tabela PLAYLIST
    playlist_data = pd.DataFrame({
        'PlayID': [701, 702, 703, 704, 705, 706, 707, 708, 709, 710],
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
        'PlayURL': ['mimi.com/playlist_vlogs', 'mimi.com/playlist_arte', 'mimi.com/playlist_tech', 
                    'mimi.com/playlist_receitas', 'mimi.com/playlist_games', 'mimi.com/playlist_viagens', 
                    'mimi.com/playlist_musica', 'mimi.com/playlist_fitness', 'mimi.com/playlist_diy', 
                    'mimi.com/playlist_estudos'],
        'PLAYTitle': ['Meus Vlogs', 'Tutoriais de Arte', 'Reviews Tech', 'Receitas Favoritas', 
                      'Melhores Gameplays', 'Viagens Incriveis', 'Covers Musicais', 'Treinos em Casa', 
                      'Projetos DIY', 'Dicas de Estudo'],
        'PLAYDesc': ['Todos os meus vlogs!', 'Aprenda arte comigo.', 'Tecnologia em foco.', 
                     'Receitas que amo fazer.', 'Gameplays epicos.', 'Minhas aventuras pelo mundo.', 
                     'Musica para todos os gostos.', 'Treinos para ficar em forma.', 'Faca voce mesmo!', 
                     'Estude melhor com essas dicas.'],
        'PLAYStatus': [True, True, True, True, True, True, True, True, True, True],
        'PLAYThum': ['thumb_vlogs.jpg', 'thumb_arte.jpg', 'thumb_tech.jpg', 'thumb_receitas.jpg', 
                      'thumb_games.jpg', 'thumb_viagens.jpg', 'thumb_musica.jpg', 'thumb_fitness.jpg', 
                      'thumb_diy.jpg', 'thumb_estudos.jpg']
    })

    # Tabela PLAYLISTCONTENT
    playlistcontent_data = pd.DataFrame({
        'ContentID': [301, 302, 303, 304, 305, 306, 307, 308, 309, 310],
        'PlayID': [701, 702, 703, 704, 705, 706, 707, 708, 709, 710],
        'CONTAddDateTimePL': [datetime(2024, 10, 8), datetime(2024, 12, 19), datetime(2024, 9, 24), 
                              datetime(2025, 3, 14), datetime(2024, 11, 29), datetime(2024, 4, 16), 
                              datetime(2024, 7, 4), datetime(2024, 8, 19), datetime(2024, 7, 14), 
                              datetime(2024, 5, 26)]
    })

    # Tabela VIDEOCOMMENT
    videocomment_data = pd.DataFrame({
        'CommentID': [501, 502, 503, 504, 505, 506, 507, 508, 509, 510],
        'ContentID': [302, 304, 306, 308, 310, 301, 303, 305, 307, 309]
    })

    # Tabela POLLCOMMENT
    pollcomment_data = pd.DataFrame({
        'CommentID': [501, 502, 503, 504, 505, 506, 507, 508, 509, 510],
        'POLLID': [601, 602, 603, 604, 605, 606, 607, 608, 609, 610]
    })

    # Tabela USERINTERACTION
    userinteraction_data = pd.DataFrame({
        'UINTID': [801, 802, 803, 804, 805, 806, 807, 808, 809, 810],
        'UserID': [102, 103, 104, 105, 106, 107, 108, 109, 110, 101],
        'UINTType': ['L', 'S', 'D', 'L', 'S', 'D', 'L', 'S', 'D', 'L']
    })

    # Tabela UCONTINT
    ucontint_data = pd.DataFrame({
        'UINTID': [801, 802, 803, 804, 805, 806, 807, 808, 809, 810],
        'ContentID': [301, 302, 303, 304, 305, 306, 307, 308, 309, 310]
    })

    # Tabela UCOMINT
    ucomint_data = pd.DataFrame({
        'UINTID': [801, 802, 803, 804, 805, 806, 807, 808, 809, 810],
        'CommentID': [501, 502, 503, 504, 505, 506, 507, 508, 509, 510]
    })

    # Tabela UPLAYINT
    uplayint_data = pd.DataFrame({
        'UINTID': [801, 802, 803, 804, 805, 806, 807, 808, 809, 810],
        'PlayID': [701, 702, 703, 704, 705, 706, 707, 708, 709, 710]
    })

    # Tabela NOTIFICATION
    notification_data = pd.DataFrame({
        'NotificationID': [901, 902, 903, 904, 905, 906, 907, 908, 909, 910],
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
        'NOTBody': ['Novo vlog disponivel!', 'Nova aula de arte!', 'Novo review no ar!', 
                    'Nova receita postada!', 'Gameplay ao vivo agora!', 'Video de viagem novo!', 
                    'Novo cover online!', 'Treino novo liberado!', 'Projeto DIY postado!', 
                    'Dica de estudo nova!']
    })

    # Tabela USERNOTIFIED
    usernotified_data = pd.DataFrame({
        'UserID': [102, 103, 104, 105, 106, 107, 108, 109, 110, 101],
        'NotificationID': [901, 902, 903, 904, 905, 906, 907, 908, 909, 910],
        'NOTSentDateTime': [datetime(2024, 10, 9), datetime(2024, 12, 20), datetime(2024, 9, 25), 
                            datetime(2025, 3, 15), datetime(2024, 11, 30), datetime(2024, 4, 17), 
                            datetime(2024, 7, 5), datetime(2024, 8, 20), datetime(2024, 7, 15), 
                            datetime(2024, 5, 27)]
    })

    # Tabela CHANNEL_CHExtLink
    channel_chextlink_data = pd.DataFrame({
        'ChannelID': [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
        'CHExtLink': ['instagram.com/lucasvlog', 'patreon.com/mariarte', 'twitter.com/techjoao', 
                      'tiktok.com/cozinhaana', 'twitch.tv/pedrogames', 'facebook.com/viagenssofia', 
                      'soundcloud.com/rafamusica', 'linkedin.com/juliafit', 'pinterest.com/carlosdiy', 
                      'discord.gg/biaestudos'],
    })

    # Tabela CONTENT_CONTTag
    content_conttag_data = pd.DataFrame({
        'CONTTag': ['paris', 'aquarela', 'iphone', 'bolo', 'cod', 'japao', 'rock', 'hiit', 'mesa', 'matematica'],
        'ContentID': [301, 302, 303, 304, 305, 306, 307, 308, 309, 310]
    })

    # Tabela PLAYLIST_PLAYTag
    playlist_playtag_data = pd.DataFrame({
        'PLAYTag': ['vlogs', 'arte', 'tech', 'receitas', 'games', 'viagens', 'musica', 'fitness', 'diy', 'estudos'],
        'PlayID': [701, 702, 703, 704, 705, 706, 707, 708, 709, 710]
    })

    # Tabela SHORT
    short_data = pd.DataFrame({
        'ContentID': [301, 302, 303, 304, 305, 306, 307, 308, 309, 310],
        'SHMusicLink': ['soundcloud.com/paris_song', 'soundcloud.com/arte_vibe', 'soundcloud.com/tech_beat', 
                        'soundcloud.com/bolo_tune', 'soundcloud.com/cod_jam', 'soundcloud.com/japan_sound', 
                        'soundcloud.com/rock_riff', 'soundcloud.com/hiit_track', 'soundcloud.com/diy_music', 
                        'soundcloud.com/study_lofi'],
        'SHORTBody': ['short_paris.mp4', 'short_aquarela.mp4', 'short_iphone.mp4', 'short_bolo.mp4', 
                      'short_cod.mp4', 'short_japao.mp4', 'short_rock.mp4', 'short_hiit.mp4', 
                      'short_mesa.mp4', 'short_matematica.mp4']
    })

    # Tabela SHORTCOMMENT
    shortcomment_data = pd.DataFrame({
        'CommentID': [501, 502, 503, 504, 505, 506, 507, 508, 509, 510],
        'ContentID': [301, 302, 303, 304, 305, 306, 307, 308, 309, 310]
    })

    # Salvar tudo em um arquivo Excel
    with pd.ExcelWriter("BD_Example_Data.xlsx") as writer:
        users_data.to_excel(writer, sheet_name='USER', index=False)
        channels_data.to_excel(writer, sheet_name='CHANNEL', index=False)
        uadminch_data.to_excel(writer, sheet_name='UADMINCH', index=False)
        uinterestch_data.to_excel(writer, sheet_name='UINTERESTCH', index=False)
        content_data.to_excel(writer, sheet_name='CONTENT', index=False)
        uwatchingcont_data.to_excel(writer, sheet_name='UWATCHINGCONT', index=False)
        live_data.to_excel(writer, sheet_name='LIVE', index=False)
        video_data.to_excel(writer, sheet_name='VIDEO', index=False)
        comment_data.to_excel(writer, sheet_name='COMMENT', index=False)
        livecomment_data.to_excel(writer, sheet_name='LIVECOMMENT', index=False)
        commentreply_data.to_excel(writer, sheet_name='COMMENTREPLY', index=False)
        poll_data.to_excel(writer, sheet_name='POLL', index=False)
        playlist_data.to_excel(writer, sheet_name='PLAYLIST', index=False)
        playlistcontent_data.to_excel(writer, sheet_name='PLAYLISTCONTENT', index=False)
        videocomment_data.to_excel(writer, sheet_name='VIDEOCOMMENT', index=False)
        pollcomment_data.to_excel(writer, sheet_name='POLLCOMMENT', index=False)
        userinteraction_data.to_excel(writer, sheet_name='USERINTERACTION', index=False)
        ucontint_data.to_excel(writer, sheet_name='UCONTINT', index=False)
        ucomint_data.to_excel(writer, sheet_name='UCOMINT', index=False)
        uplayint_data.to_excel(writer, sheet_name='UPLAYINT', index=False)
        notification_data.to_excel(writer, sheet_name='NOTIFICATION', index=False)
        usernotified_data.to_excel(writer, sheet_name='USERNOTIFIED', index=False)
        channel_chextlink_data.to_excel(writer, sheet_name='CHANNEL_CHExtLink', index=False)
        content_conttag_data.to_excel(writer, sheet_name='CONTENT_CONTTag', index=False)
        playlist_playtag_data.to_excel(writer, sheet_name='PLAYLIST_PLAYTag', index=False)
        short_data.to_excel(writer, sheet_name='SHORT', index=False)
        shortcomment_data.to_excel(writer, sheet_name='SHORTCOMMENT', index=False)

# Executar a função
generate_data()
